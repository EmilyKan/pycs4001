# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilyKan/pycs4001/blob/main/k_means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/ThousandAI/pycs4001/main/class09/k-means.csv")
data
# Out:
#             x1        x2
# 0    -2.380238  2.910056
# 1    -2.252689  3.098973
# 2    -2.544723  3.688200
# 3    -4.107467  4.661322
# 4    -2.048166  2.044703
# ...        ...       ...
# 5995 -0.345739 -2.418455
# 5996 -0.361098 -2.694880
# 5997  0.369140 -1.536031
# 5998  0.287841 -5.164405
# 5999 -1.300153 -1.943713
#
# [6000 rows x 2 columns]

# %%
x1 = np.array(data.iloc[:,0])
x2 = data.iloc[:,1].values
print(type(x1))
print(type(x2))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
plt.scatter(x1, x2, s=2)
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, max_iter=1000, random_state=1)
data = np.array(data)
np.random.shuffle(data)
kmeans.fit(data)
y_kmeans = kmeans.predict(data)
print(y_kmeans)
# Out:
# [2 0 0 ... 2 2 0]

# %%
plt.scatter(data[y_kmeans==0][:,0], data[y_kmeans==0][:,1], s = 2, color="red")
plt.scatter(data[y_kmeans==1][:,0], data[y_kmeans==1][:,1], s = 2, color="aqua")
plt.scatter(data[y_kmeans==2][:,0], data[y_kmeans==2][:,1], s = 2, color="gold")
plt.show()
